# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

# %%
# Import historic data on first prediction
data = pd.read_csv("../historic_appts_first_pred_trans.csv")
data
# Out:
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 0             10079786        52     27.45        NaN                      0
# 1             10164094        52     27.45        NaN                      1
# 2             10211058        32     39.45        NaN                      0
# 3             10550310        72     39.45        NaN                      1
# 4             10670198        32     39.45        NaN                      1
# ...                ...       ...       ...        ...                    ...
# 139238        13147714         2     27.45        NaN                      0
# 139239        13257461        67     40.00        NaN                      0
# 139240        13390142        17     27.45        NaN                      1
# 139241        13440971        77     21.70        NaN                      0
# 139242        13463451        52     27.45        NaN                      1
#
#         ethnic_category_unknown  gender_male  imd19_quintile  \
# 0                             1            1               2
# 1                             0            1               2
# 2                             1            0               2
# 3                             0            1               4
# 4                             0            0               2
# ...                         ...          ...             ...
# 139238                        0            0               1
# 139239                        0            0               1
# 139240                        0            1               3
# 139241                        1            1               2
# 139242                        0            1               2
#
#         main_spoken_language_other  current_smoker  ...   prediction_type  \
# 0                                0               0  ...  First prediction
# 1                                0               1  ...  First prediction
# 2                                0               0  ...  First prediction
# 3                                0               0  ...  First prediction
# 4                                0               1  ...  First prediction
# ...                            ...             ...  ...               ...
# 139238                           0               0  ...  First prediction
# 139239                           0               0  ...  First prediction
# 139240                           0               0  ...  First prediction
# 139241                           0               0  ...  First prediction
# 139242                           0               0  ...  First prediction
#
#         case_control  use_case   appt_date  appt_month_trans  \
# 0                1.0         3  2024-03-20                 3
# 1                1.0         3  2023-11-24                11
# 2                1.0         3  2024-01-19                 1
# 3                1.0         3  2024-01-19                 1
# 4                1.0         3  2023-12-01                12
# ...              ...       ...         ...               ...
# 139238           1.0         3  2023-12-29                12
# 139239           1.0         3  2024-02-01                 2
# 139240           1.0         3  2024-03-11                 3
# 139241           1.0         3  2024-03-20                 3
# 139242           1.0         3  2024-01-30                 1
#
#         hospital_service_display_trans  service_mapping_trans  \
# 0                                   15                      2
# 1                                   71                      2
# 2                                   71                      2
# 3                                   71                      2
# 4                                   71                      2
# ...                                ...                    ...
# 139238                              95                      8
# 139239                             125                      2
# 139240                              95                      8
# 139241                              36                      2
# 139242                             133                     10
#
#         reason_display_trans  appointment_type_trans  \
# 0                         76                       0
# 1                        376                       0
# 2                        376                       0
# 3                        376                       0
# 4                        376                       0
# ...                      ...                     ...
# 139238                   499                       0
# 139239                   694                       0
# 139240                   452                       0
# 139241                   215                       1
# 139242                   746                       1
#
#         did_not_attend_risk_group_trans
# 0                                     3
# 1                                     3
# 2                                     1
# 3                                     1
# 4                                     3
# ...                                 ...
# 139238                                2
# 139239                                2
# 139240                                3
# 139241                                2
# 139242                                3
#
# [139243 rows x 57 columns]

# %%
# Filter for adult ENT appointments only
ent_codes = [6, 23,  1,  8, 17, 20, 21, 22,  0, 13, 28, 14, 15,  3, 26, 18, 25, 2, 24, 27, 11,  4, 12, 19,  5, 16,  9,  7, 10]
data = data[data["reason_display_trans"].isin(ent_codes)]
data
# Out:
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 17            12088942        42     27.45        NaN                      0
# 20            12207851        42     27.45        NaN                      1
# 36            12791383        27     21.70        NaN                      0
# 41            12940266        42     27.45        NaN                      1
# 68            13428133        83     21.70        NaN                      0
# ...                ...       ...       ...        ...                    ...
# 139155        20238919        42     21.70        NaN                      0
# 139227        11138651        47     27.45        NaN                      0
# 139233        12468296        52     27.45        NaN                      0
# 139234        12799747        72     21.70        NaN                      0
# 139235        12985218        42     27.45        NaN                      0
#
#         ethnic_category_unknown  gender_male  imd19_quintile  \
# 17                            0            0               4
# 20                            0            1               4
# 36                            0            0               3
# 41                            0            0               2
# 68                            0            0               2
# ...                         ...          ...             ...
# 139155                        0            0               2
# 139227                        0            0               2
# 139233                        0            0               1
# 139234                        0            0               2
# 139235                        0            0               2
#
#         main_spoken_language_other  current_smoker  ...   prediction_type  \
# 17                               0               1  ...  First prediction
# 20                               0               0  ...  First prediction
# 36                               0               0  ...  First prediction
# 41                               0               0  ...  First prediction
# 68                               0               0  ...  First prediction
# ...                            ...             ...  ...               ...
# 139155                           0               1  ...  First prediction
# 139227                           0               0  ...  First prediction
# 139233                           0               1  ...  First prediction
# 139234                           0               1  ...  First prediction
# 139235                           0               0  ...  First prediction
#
#         case_control  use_case   appt_date  appt_month_trans  \
# 17               1.0         3  2024-02-14                 2
# 20               1.0         3  2024-03-12                 3
# 36               1.0         3  2024-01-31                 1
# 41               1.0         3  2024-04-03                 4
# 68               1.0         3  2024-04-05                 4
# ...              ...       ...         ...               ...
# 139155           1.0         3  2024-04-23                 4
# 139227           1.0         3  2024-02-20                 2
# 139233           1.0         3  2023-11-25                11
# 139234           1.0         3  2023-12-08                12
# 139235           1.0         3  2024-04-19                 4
#
#         hospital_service_display_trans  service_mapping_trans  \
# 17                                   3                     10
# 20                                   3                     10
# 36                                   3                     10
# 41                                   3                     10
# 68                                   3                     10
# ...                                ...                    ...
# 139155                             111                      9
# 139227                               3                     10
# 139233                               3                     10
# 139234                             111                      9
# 139235                               3                     10
#
#         reason_display_trans  appointment_type_trans  \
# 17                         6                       0
# 20                         6                       0
# 36                         6                       0
# 41                         6                       0
# 68                         6                       0
# ...                      ...                     ...
# 139155                     9                       0
# 139227                     6                       0
# 139233                     6                       0
# 139234                     6                       0
# 139235                     6                       0
#
#         did_not_attend_risk_group_trans
# 17                                    3
# 20                                    4
# 36                                    2
# 41                                    1
# 68                                    3
# ...                                 ...
# 139155                                1
# 139227                                3
# 139233                                3
# 139234                                2
# 139235                                3
#
# [5793 rows x 57 columns]

# %%
# Export historic adult ENT appointments (First Prediction) to CSV
data.to_csv("../historic_appts_first_pred_trans_ENT.csv", index=False)

# %%
# Calculate the total number of appointments
total_appts = data.shape[0]
total_appts
# Out:
# 5793

# %% [markdown]
# ### Risk category scenario 1
# - Predicted no show: very high risk
# - Predicted show: high, moderate, low risk

# %%
# Transform risk categories to binary
risk_mapping ={
    1: 0, # Low risk
    2: 0, # Moderate risk
    3: 0, # High risk
    4: 1 # Very high risk
}

# Map the month names to numbers
trans_data1 = data.copy()
trans_data1["pred_no_show"] = trans_data1["did_not_attend_risk_group_trans"].map(risk_mapping)

trans_data1[["no_show", "did_not_attend_risk_group_trans", "pred_no_show"]]
# Out:
#         no_show  did_not_attend_risk_group_trans  pred_no_show
# 17          0.0                                3             0
# 20          0.0                                4             1
# 36          0.0                                2             0
# 41          0.0                                1             0
# 68          0.0                                3             0
# ...         ...                              ...           ...
# 139155      0.0                                1             0
# 139227      0.0                                3             0
# 139233      0.0                                3             0
# 139234      0.0                                2             0
# 139235      0.0                                3             0
#
# [5793 rows x 3 columns]

# %%
# Calculate confusion matrix
cm1 = confusion_matrix(trans_data1["no_show"], trans_data1["pred_no_show"])
cm1
# Out:
# array([[4977,   57],
#        [ 678,   81]])

# %%
trans_data1.loc[trans_data1["no_show"] == 1]
# Out:
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 132           14071855        42     40.00        NaN                      0
# 183           14390588        42     27.45        NaN                      0
# 219           14609191        47     27.45        NaN                      0
# 238           14707395        52     39.45        NaN                      0
# 312           14963998        27     27.45        NaN                      0
# ...                ...       ...       ...        ...                    ...
# 137620        20171165         2     27.45        NaN                      0
# 137865        20177551        27     27.45        NaN                      0
# 138451        20201487         2     27.45        NaN                      1
# 138591        20206525        57     21.70        NaN                      1
# 138867        20219731        27     39.45        NaN                      0
#
#         ethnic_category_unknown  gender_male  imd19_quintile  \
# 132                           0            1               3
# 183                           0            1               3
# 219                           0            1               1
# 238                           0            1               2
# 312                           1            1               2
# ...                         ...          ...             ...
# 137620                        0            1               2
# 137865                        1            0               1
# 138451                        0            1               1
# 138591                        0            0               3
# 138867                        0            0               3
#
#         main_spoken_language_other  current_smoker  ...  case_control  \
# 132                              0               1  ...           1.0
# 183                              1               0  ...           1.0
# 219                              0               0  ...           1.0
# 238                              0               1  ...           1.0
# 312                              0               0  ...           1.0
# ...                            ...             ...  ...           ...
# 137620                           0               0  ...           1.0
# 137865                           0               0  ...           1.0
# 138451                           0               0  ...           1.0
# 138591                           0               1  ...           1.0
# 138867                           0               1  ...           1.0
#
#         use_case   appt_date  appt_month_trans  \
# 132            3  2023-12-05                12
# 183            3  2024-04-18                 4
# 219            3  2024-04-05                 4
# 238            3  2024-02-23                 2
# 312            3  2024-02-29                 2
# ...          ...         ...               ...
# 137620         3  2024-04-15                 4
# 137865         3  2024-04-16                 4
# 138451         3  2024-04-22                 4
# 138591         3  2024-04-23                 4
# 138867         3  2024-04-22                 4
#
#         hospital_service_display_trans  service_mapping_trans  \
# 132                                111                      9
# 183                                  3                     10
# 219                                111                      9
# 238                                111                      9
# 312                                  3                     10
# ...                                ...                    ...
# 137620                              92                      8
# 137865                               3                     10
# 138451                               3                     10
# 138591                               3                     10
# 138867                               3                     10
#
#         reason_display_trans  appointment_type_trans  \
# 132                        6                       0
# 183                        6                       0
# 219                        6                       0
# 238                        6                       0
# 312                        6                       0
# ...                      ...                     ...
# 137620                    14                       0
# 137865                     4                       0
# 138451                     3                       0
# 138591                     6                       0
# 138867                     4                       0
#
#         did_not_attend_risk_group_trans  pred_no_show
# 132                                   2             0
# 183                                   3             0
# 219                                   3             0
# 238                                   3             0
# 312                                   3             0
# ...                                 ...           ...
# 137620                                1             0
# 137865                                3             0
# 138451                                3             0
# 138591                                1             0
# 138867                                2             0
#
# [759 rows x 58 columns]

# %%
# Calculate PPV (Precision) ie. TP / (TP + FP)
TN1, FP1, FN1, TP1 = cm1.ravel()

PPV1 = TP1 / (TP1 + FP1)
PPV1
# Out:
# 0.5869565217391305

# %%
# Calculate true no-show %
true_no_show1 = TP1/total_appts
true_no_show1
# Out:
# 0.013982392542723977

# %% [markdown]
# ### Risk category scenario 2
# - Predicted no show: very high, high risk
# - Predicted show: moderate, low risk

# %%
# Transform risk categories to binary
risk_mapping ={
    1: 0, # Low risk
    2: 0, # Moderate risk
    3: 1, # High risk
    4: 1 # Very high risk
}

# Map the month names to numbers
trans_data2 = data.copy()
trans_data2["pred_no_show"] = trans_data2["did_not_attend_risk_group_trans"].map(risk_mapping)

trans_data2[["no_show", "did_not_attend_risk_group_trans", "pred_no_show"]]
# Out:
#         no_show  did_not_attend_risk_group_trans  pred_no_show
# 17          0.0                                3             1
# 20          0.0                                4             1
# 36          0.0                                2             0
# 41          0.0                                1             0
# 68          0.0                                3             1
# ...         ...                              ...           ...
# 139155      0.0                                1             0
# 139227      0.0                                3             1
# 139233      0.0                                3             1
# 139234      0.0                                2             0
# 139235      0.0                                3             1
#
# [5793 rows x 3 columns]

# %%
# Calculate confusion matrix
cm2 = confusion_matrix(trans_data2["no_show"], trans_data2["pred_no_show"])
cm2
# Out:
# array([[4041,  993],
#        [ 383,  376]])

# %%
# Calculate PPV (Precision) ie. TP / (TP + FP)
TN2, FP2, FN2, TP2 = cm2.ravel()

PPV2 = TP2 / (TP2 + FP2)
PPV2
# Out:
# 0.27465303140978814

# %%
# Calculate true no-show %
true_no_show2 = TP2/total_appts
true_no_show2
# Out:
# 0.06490592093906439

# %% [markdown]
# ### Risk category scenario 3
# - Predicted no show: very high, high risk, moderate
# - Predicted show: low risk

# %%
# Transform risk categories to binary
risk_mapping ={
 1: 0, # Low risk
    2: 1, # Moderate risk
    3: 1, # High risk
    4: 1 # Very high risk
}

# Map the month names to numbers
trans_data3 = data.copy()
trans_data3["pred_no_show"] = trans_data3["did_not_attend_risk_group_trans"].map(risk_mapping)

trans_data3[["no_show", "did_not_attend_risk_group_trans", "pred_no_show"]]
# Out:
#         no_show  did_not_attend_risk_group_trans  pred_no_show
# 17          0.0                                3             1
# 20          0.0                                4             1
# 36          0.0                                2             1
# 41          0.0                                1             0
# 68          0.0                                3             1
# ...         ...                              ...           ...
# 139155      0.0                                1             0
# 139227      0.0                                3             1
# 139233      0.0                                3             1
# 139234      0.0                                2             1
# 139235      0.0                                3             1
#
# [5793 rows x 3 columns]

# %%
# Calculate confusion matrix
cm3 = confusion_matrix(trans_data3["no_show"], trans_data3["pred_no_show"])
cm3
# Out:
# array([[2547, 2487],
#        [ 159,  600]])

# %%
# Calculate PPV (Precision) ie. TP / (TP + FP)
TN3, FP3, FN3, TP3 = cm3.ravel()

PPV3 = TP3 / (TP3 + FP3)
PPV3
# Out:
# 0.19436345966958213

# %%
# Calculate true no-show %
true_no_show3 = TP3/total_appts
true_no_show3
# Out:
# 0.10357327809425168

# %%
# Store the PPV1 value for later access in other Jupyter Notebook scripts
# %store PPV1
# %store PPV2
# Out:
# Stored 'PPV1' (float64)
# Stored 'PPV2' (float64)
