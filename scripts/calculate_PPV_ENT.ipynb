# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

# %%
# Import historic data on first prediction
data = pd.read_csv("../historic_first_pred.csv")
data
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_56548/2471409024.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../historic_first_pred.csv")
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 0             10079786        52     27.45        NaN                      0
# 1             10164094        52     27.45        NaN                      1
# 2             10211058        32     39.45        NaN                      0
# 3             10550310        72     39.45        NaN                      1
# 4             10670198        32     39.45        NaN                      1
# ...                ...       ...       ...        ...                    ...
# 139396        13147714         2     27.45        NaN                      0
# 139397        13257461        67     40.00        NaN                      0
# 139398        13390142        17     27.45        NaN                      1
# 139399        13440971        77     21.70        NaN                      0
# 139400        13463451        52     27.45        NaN                      1
#
#         ethnic_category_unknown  gender_male  imd19_quintile  \
# 0                             1            1               2
# 1                             0            1               2
# 2                             1            0               2
# 3                             0            1               4
# 4                             0            0               2
# ...                         ...          ...             ...
# 139396                        0            0               1
# 139397                        0            0               1
# 139398                        0            1               3
# 139399                        1            1               2
# 139400                        0            1               2
#
#         main_spoken_language_other  current_smoker  ...   prediction_type  \
# 0                                0               0  ...  First prediction
# 1                                0               1  ...  First prediction
# 2                                0               0  ...  First prediction
# 3                                0               0  ...  First prediction
# 4                                0               1  ...  First prediction
# ...                            ...             ...  ...               ...
# 139396                           0               0  ...  First prediction
# 139397                           0               0  ...  First prediction
# 139398                           0               0  ...  First prediction
# 139399                           0               0  ...  First prediction
# 139400                           0               0  ...  First prediction
#
#         case_control  use_case   appt_date  appt_month_trans  \
# 0                1.0         3  2024-03-20               3.0
# 1                1.0         3  2023-11-24              11.0
# 2                1.0         3  2024-01-19               1.0
# 3                1.0         3  2024-01-19               1.0
# 4                1.0         3  2023-12-01              12.0
# ...              ...       ...         ...               ...
# 139396           1.0         3  2023-12-29              12.0
# 139397           1.0         3  2024-02-01               2.0
# 139398           1.0         3  2024-03-11               3.0
# 139399           1.0         3  2024-03-20               3.0
# 139400           1.0         3  2024-01-30               1.0
#
#         hospital_service_display_trans  service_mapping_trans  \
# 0                                   15                      2
# 1                                   71                      2
# 2                                   71                      2
# 3                                   71                      2
# 4                                   71                      2
# ...                                ...                    ...
# 139396                              95                      8
# 139397                             125                      2
# 139398                              95                      8
# 139399                              36                      2
# 139400                             133                     10
#
#         reason_display_trans  appointment_type_trans  \
# 0                         76                       0
# 1                        376                       0
# 2                        376                       0
# 3                        376                       0
# 4                        376                       0
# ...                      ...                     ...
# 139396                   499                       0
# 139397                   694                       0
# 139398                   452                       0
# 139399                   215                       1
# 139400                   746                       1
#
#         did_not_attend_risk_group_trans
# 0                                     3
# 1                                     3
# 2                                     1
# 3                                     1
# 4                                     3
# ...                                 ...
# 139396                                2
# 139397                                2
# 139398                                3
# 139399                                2
# 139400                                3
#
# [139401 rows x 58 columns]

# %%
# Filter for adult ENT appointments only
ent_codes = [6, 23,  1,  8, 17, 20, 21, 22,  0, 13, 28, 14, 15,  3, 26, 18, 25, 2, 24, 27, 11,  4, 12, 19,  5, 16,  9,  7, 10]
data = data[data["reason_display_trans"].isin(ent_codes)]
data
# Out:
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 17            12088942        42     27.45        NaN                      0
# 20            12207851        42     27.45        NaN                      1
# 36            12791383        27     21.70        NaN                      0
# 41            12940266        42     27.45        NaN                      1
# 68            13428133        83     21.70        NaN                      0
# ...                ...       ...       ...        ...                    ...
# 139313        20238919        42     21.70        NaN                      0
# 139385        11138651        47     27.45        NaN                      0
# 139391        12468296        52     27.45        NaN                      0
# 139392        12799747        72     21.70        NaN                      0
# 139393        12985218        42     27.45        NaN                      0
#
#         ethnic_category_unknown  gender_male  imd19_quintile  \
# 17                            0            0               4
# 20                            0            1               4
# 36                            0            0               3
# 41                            0            0               2
# 68                            0            0               2
# ...                         ...          ...             ...
# 139313                        0            0               2
# 139385                        0            0               2
# 139391                        0            0               1
# 139392                        0            0               2
# 139393                        0            0               2
#
#         main_spoken_language_other  current_smoker  ...   prediction_type  \
# 17                               0               1  ...  First prediction
# 20                               0               0  ...  First prediction
# 36                               0               0  ...  First prediction
# 41                               0               0  ...  First prediction
# 68                               0               0  ...  First prediction
# ...                            ...             ...  ...               ...
# 139313                           0               1  ...  First prediction
# 139385                           0               0  ...  First prediction
# 139391                           0               1  ...  First prediction
# 139392                           0               1  ...  First prediction
# 139393                           0               0  ...  First prediction
#
#         case_control  use_case   appt_date  appt_month_trans  \
# 17               1.0         3  2024-02-14               2.0
# 20               1.0         3  2024-03-12               3.0
# 36               1.0         3  2024-01-31               1.0
# 41               1.0         3  2024-04-03               4.0
# 68               1.0         3  2024-04-05               4.0
# ...              ...       ...         ...               ...
# 139313           1.0         3  2024-04-23               4.0
# 139385           1.0         3  2024-02-20               2.0
# 139391           1.0         3  2023-11-25              11.0
# 139392           1.0         3  2023-12-08              12.0
# 139393           1.0         3  2024-04-19               4.0
#
#         hospital_service_display_trans  service_mapping_trans  \
# 17                                   3                     10
# 20                                   3                     10
# 36                                   3                     10
# 41                                   3                     10
# 68                                   3                     10
# ...                                ...                    ...
# 139313                             111                      9
# 139385                               3                     10
# 139391                               3                     10
# 139392                             111                      9
# 139393                               3                     10
#
#         reason_display_trans  appointment_type_trans  \
# 17                         6                       0
# 20                         6                       0
# 36                         6                       0
# 41                         6                       0
# 68                         6                       0
# ...                      ...                     ...
# 139313                     9                       0
# 139385                     6                       0
# 139391                     6                       0
# 139392                     6                       0
# 139393                     6                       0
#
#         did_not_attend_risk_group_trans
# 17                                    3
# 20                                    4
# 36                                    2
# 41                                    1
# 68                                    3
# ...                                 ...
# 139313                                1
# 139385                                3
# 139391                                3
# 139392                                2
# 139393                                3
#
# [5795 rows x 58 columns]

# %%
# Calculate the total number of appointments
total_appts = data.shape[0]
total_appts
# Out:
# 5795

# %% [markdown]
# ### Risk category scenario 1
# - Predicted no show: very high risk
# - Predicted show: high, moderate, low risk

# %%
# Transform risk categories to binary
risk_mapping ={
    1: 0, # Low risk
    2: 0, # Moderate risk
    3: 0, # High risk
    4: 1 # Very high risk
}

# Map the month names to numbers
trans_data1 = data.copy()
trans_data1["pred_no_show"] = trans_data1["did_not_attend_risk_group_trans"].map(risk_mapping)

trans_data1[["no_show", "did_not_attend_risk_group_trans", "pred_no_show"]]
# Out:
#         no_show  did_not_attend_risk_group_trans  pred_no_show
# 17          0.0                                3             0
# 20          0.0                                4             1
# 36          0.0                                2             0
# 41          0.0                                1             0
# 68          0.0                                3             0
# ...         ...                              ...           ...
# 139313      0.0                                1             0
# 139385      0.0                                3             0
# 139391      0.0                                3             0
# 139392      0.0                                2             0
# 139393      0.0                                3             0
#
# [5795 rows x 3 columns]

# %%
# Calculate confusion matrix
cm1 = confusion_matrix(trans_data1["no_show"], trans_data1["pred_no_show"])
cm1
# Out:
# array([[4977,   57],
#        [ 680,   81]])

# %%
# Calculate PPV (Precision) ie. TP / (TP + FP)
TN1, FP1, FN1, TP1 = cm1.ravel()

PPV1 = TP1 / (TP1 + FP1)
PPV1
# Out:
# 0.5869565217391305

# %%
# Calculate true no-show %
true_no_show1 = TP1/total_appts
true_no_show1
# Out:
# 0.013977566867989646

# %% [markdown]
# ### Risk category scenario 2
# - Predicted no show: very high, high risk
# - Predicted show: moderate, low risk

# %%
# Transform risk categories to binary
risk_mapping ={
    1: 0, # Low risk
    2: 0, # Moderate risk
    3: 1, # High risk
    4: 1 # Very high risk
}

# Map the month names to numbers
trans_data2 = data.copy()
trans_data2["pred_no_show"] = trans_data2["did_not_attend_risk_group_trans"].map(risk_mapping)

trans_data2[["no_show", "did_not_attend_risk_group_trans", "pred_no_show"]]
# Out:
#         no_show  did_not_attend_risk_group_trans  pred_no_show
# 17          0.0                                3             1
# 20          0.0                                4             1
# 36          0.0                                2             0
# 41          0.0                                1             0
# 68          0.0                                3             1
# ...         ...                              ...           ...
# 139313      0.0                                1             0
# 139385      0.0                                3             1
# 139391      0.0                                3             1
# 139392      0.0                                2             0
# 139393      0.0                                3             1
#
# [5795 rows x 3 columns]

# %%
# Calculate confusion matrix
cm2 = confusion_matrix(trans_data2["no_show"], trans_data2["pred_no_show"])
cm2
# Out:
# array([[4041,  993],
#        [ 384,  377]])

# %%
# Calculate PPV (Precision) ie. TP / (TP + FP)
TN2, FP2, FN2, TP2 = cm2.ravel()

PPV2 = TP2 / (TP2 + FP2)
PPV2
# Out:
# 0.2751824817518248

# %%
# Calculate true no-show %
true_no_show2 = TP2/total_appts
true_no_show2
# Out:
# 0.06505608283002588

# %% [markdown]
# ### Risk category scenario 3
# - Predicted no show: very high, high risk, moderate
# - Predicted show: low risk

# %%
# Transform risk categories to binary
risk_mapping ={
 1: 0, # Low risk
    2: 1, # Moderate risk
    3: 1, # High risk
    4: 1 # Very high risk
}

# Map the month names to numbers
trans_data3 = data.copy()
trans_data3["pred_no_show"] = trans_data3["did_not_attend_risk_group_trans"].map(risk_mapping)

trans_data3[["no_show", "did_not_attend_risk_group_trans", "pred_no_show"]]
# Out:
#         no_show  did_not_attend_risk_group_trans  pred_no_show
# 17          0.0                                3             1
# 20          0.0                                4             1
# 36          0.0                                2             1
# 41          0.0                                1             0
# 68          0.0                                3             1
# ...         ...                              ...           ...
# 139313      0.0                                1             0
# 139385      0.0                                3             1
# 139391      0.0                                3             1
# 139392      0.0                                2             1
# 139393      0.0                                3             1
#
# [5795 rows x 3 columns]

# %%
# Calculate confusion matrix
cm3 = confusion_matrix(trans_data3["no_show"], trans_data3["pred_no_show"])
cm3
# Out:
# array([[2547, 2487],
#        [ 160,  601]])

# %%
# Calculate PPV (Precision) ie. TP / (TP + FP)
TN3, FP3, FN3, TP3 = cm3.ravel()

PPV3 = TP3 / (TP3 + FP3)
PPV3
# Out:
# 0.19462435233160622

# %%
# Calculate true no-show %
true_no_show3 = TP3/total_appts
true_no_show3
# Out:
# 0.10371009490940467

# %%
# Store the PPV1 value for later access in other Jupyter Notebook scripts
# %store PPV1
# Out:
# Stored 'PPV1' (float64)
