# %%
#!pip install jupyter-datatables
import pandas as pd
# from jupyter_datatables import init_datatables_mode

# # Load the jupyter_require extension
# %load_ext jupyter_require
# init_datatables_mode()

# %%
# Import raw data
data = pd.read_csv("../historic_appts_trans.csv")
data
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_50044/1461436612.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../historic_appts_trans.csv")
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 0             10079786        52     27.45        NaN                      0
# 1             10079786        52     39.45        NaN                      1
# 2             10164094        52     27.45        NaN                      1
# 3             10164094        52     27.45        NaN                      1
# 4             10211058        32     39.45        NaN                      0
# ...                ...       ...       ...        ...                    ...
# 278794        13390142        17     27.45        NaN                      1
# 278795        13440971        77     21.70        NaN                      0
# ...

# %%
# Keep appointments with 'First prediction' (because 'Last prediction' is 'future' behaviour)
first_pred = data[data['prediction_type'] == 'First prediction']
first_pred
# Out:
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 0             10079786        52     27.45        NaN                      0
# 3             10164094        52     27.45        NaN                      1
# 4             10211058        32     39.45        NaN                      0
# 6             10550310        72     39.45        NaN                      1
# 8             10670198        32     39.45        NaN                      1
# ...                ...       ...       ...        ...                    ...
# 278790        13147714         2     27.45        NaN                      0
# 278791        13257461        67     40.00        NaN                      0
# 278793        13390142        17     27.45        NaN                      1
# 278795        13440971        77     21.70        NaN                      0
# 278797        13463451        52     27.45        NaN                      1
#
# ...

# %%
# Export data to CSV
first_pred.to_csv("../historic_first_pred.csv", index=False)
