# %%
import pandas as pd
from sklearn import preprocessing

# %%
# Import raw data
data = pd.read_csv('../historic_appts_first_pred_raw.csv')
data
# Out:
#         appointment_id  age_deid  bmi_deid  ethnicity  ethnic_category_black  \
# 0             10079786        52     27.45        NaN                      0
# 1             10164094        52     27.45        NaN                      1
# 2             10211058        32     39.45        NaN                      0
# 3             10550310        72     39.45        NaN                      1
# 4             10670198        32     39.45        NaN                      1
# ...                ...       ...       ...        ...                    ...
# 139238        13147714         2     27.45        NaN                      0
# 139239        13257461        67     40.00        NaN                      0
# 139240        13390142        17     27.45        NaN                      1
# 139241        13440971        77     21.70        NaN                      0
# 139242        13463451        52     27.45        NaN                      1
#
#         ethnic_category_unknown  gender_male  imd19_quintile  \
# 0                             1            1               2
# 1                             0            1               2
# 2                             1            0               2
# 3                             0            1               4
# 4                             0            0               2
# ...                         ...          ...             ...
# 139238                        0            0               1
# 139239                        0            0               1
# 139240                        0            1               3
# 139241                        1            1               2
# 139242                        0            1               2
#
#         main_spoken_language_other  current_smoker  ...  \
# 0                                0               0  ...
# 1                                0               1  ...
# 2                                0               0  ...
# 3                                0               0  ...
# 4                                0               1  ...
# ...                            ...             ...  ...
# 139238                           0               0  ...
# 139239                           0               0  ...
# 139240                           0               0  ...
# 139241                           0               0  ...
# 139242                           0               0  ...
#
#         service_mapping_priority  service_mapping_surgical  weekswaiting  \
# 0                              0                         0           NaN
# 1                              0                         0           NaN
# 2                              0                         0           NaN
# 3                              0                         0           NaN
# 4                              0                         0           NaN
# ...                          ...                       ...           ...
# 139238                         0                         0           NaN
# 139239                         0                         0           NaN
# 139240                         0                         0           NaN
# 139241                         0                         0           NaN
# 139242                         0                         1           NaN
#
#         no_show did_not_attend_risk  did_not_attend_risk_group  \
# 0           0.0            0.264963                  High Risk
# 1           1.0            0.266140                  High Risk
# 2           1.0            0.062844                   Low Risk
# 3           0.0            0.040898                   Low Risk
# 4           1.0            0.389798                  High Risk
# ...         ...                 ...                        ...
# 139238      1.0            0.160467              Moderate Risk
# 139239      0.0            0.124008              Moderate Risk
# 139240      1.0            0.235887                  High Risk
# 139241      1.0            0.163437              Moderate Risk
# 139242      0.0            0.292078                  High Risk
#
#          prediction_type case_control use_case   appt_date
# 0       First prediction          1.0        3  2024-03-20
# 1       First prediction          1.0        3  2023-11-24
# 2       First prediction          1.0        3  2024-01-19
# 3       First prediction          1.0        3  2024-01-19
# 4       First prediction          1.0        3  2023-12-01
# ...                  ...          ...      ...         ...
# 139238  First prediction          1.0        3  2023-12-29
# 139239  First prediction          1.0        3  2024-02-01
# 139240  First prediction          1.0        3  2024-03-11
# 139241  First prediction          1.0        3  2024-03-20
# 139242  First prediction          1.0        3  2024-01-30
#
# [139243 rows x 57 columns]

# %%
# Check for missing values ie. columns aviailable for analysis
data.isnull().sum()
# Out:
# appointment_id                               0
# age_deid                                     0
# bmi_deid                                     0
# ethnicity                               139243
# ethnic_category_black                        0
# ethnic_category_unknown                      0
# gender_male                                  0
# imd19_quintile                               0
# main_spoken_language_other                   0
# current_smoker                               0
# substance_misuse                             0
# smoking_unknown                              0
# tfc_name                                139243
# patient_on_multiple_pathways            139243
# appt_month                                   0
# appt_hour                                    0
# appt_duration                                0
# hospital_service_display                   397
# service_mapping                              0
# reason_display                               0
# appointment_type                             0
# new_appt_flag                                0
# appointment_type_telephone                   0
# appt_hour_11am_to_12pm                       0
# appt_hour_12pm_to_1pm                        0
# appt_hour_2pm_to_3pm                         0
# appt_season_winter                           0
# days_last_appt                               0
# emergency_enc_last_12m_one_or_two            0
# emergency_enc_last_12m_three_or_more         0
# lead_time                                    0
# ltc_count                                    0
# ns_rate_seq                                  0
# num_reschedules_one                          0
# num_reschedules_two_or_more                  0
# op_appts_last_12m                            0
# osrm_drive_time                              0
# other_vulnerability                          0
# past_no_show_count_one                       0
# past_no_show_count_three_or_more             0
# past_no_show_count_two                       0
# past_no_show_rate                            0
# phone_number                                 0
# physically_inactive                          0
# safeguarding                                 0
# service_mapping_allied_hcp_therapy           0
# service_mapping_paeds                        0
# service_mapping_priority                     0
# service_mapping_surgical                     0
# weekswaiting                            139243
# no_show                                      0
# did_not_attend_risk                          0
# did_not_attend_risk_group                    0
# prediction_type                              0
# case_control                                 0
# use_case                                     0
# appt_date                                    0
# dtype: int64

# %%
# count number of unique appointment IDs
data[data["case_control"]==1]["appointment_id"].nunique()
# Out:
# 139243

# %%
# Average did_not_attend risk score
data[(data["did_not_attend_risk_group"]=="High Risk")|(data["did_not_attend_risk_group"]=="Very High Risk")]["did_not_attend_risk"].mean()
# Out:
# 0.27078719642882415

# %% [markdown]
# ### Transform date from object to datetime

# %%
data["appt_date"] = pd.to_datetime(data["appt_date"])
data["appt_date"]
# Out:
# 0        2024-03-20
# 1        2023-11-24
# 2        2024-01-19
# 3        2024-01-19
# 4        2023-12-01
#             ...
# 139238   2023-12-29
# 139239   2024-02-01
# 139240   2024-03-11
# 139241   2024-03-20
# 139242   2024-01-30
# Name: appt_date, Length: 139243, dtype: datetime64[ns]

# %% [markdown]
# ### Transform categorical data to numeric data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139243 entries, 0 to 139242
# Data columns (total 57 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   appointment_id                        139243 non-null  int64
#  1   age_deid                              139243 non-null  int64
#  2   bmi_deid                              139243 non-null  float64
#  3   ethnicity                             0 non-null       float64
#  4   ethnic_category_black                 139243 non-null  int64
#  5   ethnic_category_unknown               139243 non-null  int64
#  6   gender_male                           139243 non-null  int64
#  7   imd19_quintile                        139243 non-null  int64
#  8   main_spoken_language_other            139243 non-null  int64
#  9   current_smoker                        139243 non-null  int64
#  10  substance_misuse                      139243 non-null  int64
#  11  smoking_unknown                       139243 non-null  int64
#  12  tfc_name                              0 non-null       float64
#  13  patient_on_multiple_pathways          0 non-null       float64
#  14  appt_month                            139243 non-null  object
#  15  appt_hour                             139243 non-null  float64
#  16  appt_duration                         139243 non-null  float64
#  17  hospital_service_display              138846 non-null  object
#  18  service_mapping                       139243 non-null  object
#  19  reason_display                        139243 non-null  object
#  20  appointment_type                      139243 non-null  object
#  21  new_appt_flag                         139243 non-null  int64
#  22  appointment_type_telephone            139243 non-null  int64
#  23  appt_hour_11am_to_12pm                139243 non-null  int64
#  24  appt_hour_12pm_to_1pm                 139243 non-null  int64
#  25  appt_hour_2pm_to_3pm                  139243 non-null  int64
#  26  appt_season_winter                    139243 non-null  int64
#  27  days_last_appt                        139243 non-null  int64
#  28  emergency_enc_last_12m_one_or_two     139243 non-null  int64
#  29  emergency_enc_last_12m_three_or_more  139243 non-null  int64
#  30  lead_time                             139243 non-null  int64
#  31  ltc_count                             139243 non-null  int64
#  32  ns_rate_seq                           139243 non-null  float64
#  33  num_reschedules_one                   139243 non-null  int64
#  34  num_reschedules_two_or_more           139243 non-null  int64
#  35  op_appts_last_12m                     139243 non-null  int64
#  36  osrm_drive_time                       139243 non-null  float64
#  37  other_vulnerability                   139243 non-null  int64
#  38  past_no_show_count_one                139243 non-null  int64
#  39  past_no_show_count_three_or_more      139243 non-null  int64
#  40  past_no_show_count_two                139243 non-null  int64
#  41  past_no_show_rate                     139243 non-null  float64
#  42  phone_number                          139243 non-null  int64
#  43  physically_inactive                   139243 non-null  int64
#  44  safeguarding                          139243 non-null  int64
#  45  service_mapping_allied_hcp_therapy    139243 non-null  int64
#  46  service_mapping_paeds                 139243 non-null  int64
#  47  service_mapping_priority              139243 non-null  int64
#  48  service_mapping_surgical              139243 non-null  int64
#  49  weekswaiting                          0 non-null       float64
#  50  no_show                               139243 non-null  float64
#  51  did_not_attend_risk                   139243 non-null  float64
#  52  did_not_attend_risk_group             139243 non-null  object
#  53  prediction_type                       139243 non-null  object
#  54  case_control                          139243 non-null  float64
#  55  use_case                              139243 non-null  int64
#  56  appt_date                             139243 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(13), int64(36), object(7)
# memory usage: 60.6+ MB

# %%
# Encode the appt_month column

month_mapping ={
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August": 8,
    "September": 9,
    "October": 10,
    "November": 11,
    "December": 12
}

# Map the month names to numbers
data["appt_month_trans"] = data["appt_month"].map(month_mapping)

data[['appt_month', 'appt_month_trans']]
# Out:
#        appt_month  appt_month_trans
# 0           March                 3
# 1        November                11
# 2         January                 1
# 3         January                 1
# 4        December                12
# ...           ...               ...
# 139238   December                12
# 139239   February                 2
# 139240      March                 3
# 139241      March                 3
# 139242    January                 1
#
# [139243 rows x 2 columns]

# %%
# Encode the hospital_service_display column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(data["hospital_service_display"])

# Add the encoded column to the data
data["hospital_service_display_trans"] = label

# %%
# Encode the service_mapping column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(data["service_mapping"])

# Add the encoded column to the data
data["service_mapping_trans"] = label

# %%
# Encode the reason_display column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(data["reason_display"])

# Add the encoded column to the data
data["reason_display_trans"] = label

# %%
# Find out the codes for reason_display that contain 'adult ENT'
print(data[data["reason_display"].str.contains("adult ENT", case=False, na=False)]["reason_display"].unique())
ent_appts = data[data["reason_display"].str.contains("adult ENT", case=False, na=False)]
ent_codes = ent_appts["reason_display_trans"].unique()
ent_codes
# Out:
# ['Adult ENT F/Up' 'Adult ENT Voice Clinic New' 'Adult ENT Balance F/Up'
#  'Adult ENT New' 'Adult ENT Thyroid F/Up' 'Adult ENT Voice Clinic F/Up'
#  'Adult ENT Voice Clinic JT F/Up' 'Adult ENT Voice Clinic JT New'
#  'Adult ENT BIPP F/Up' 'Adult ENT Post Op F/Up'
#  'Adult ENT Voice Post Op F/Up' 'Adult ENT Pre-Assessment F/Up'
#  'Adult ENT Results F/Up' 'Adult ENT Emergency Clinic F/Up'
#  'Adult ENT Voice Osteopath F/Up' 'Adult ENT Thyroid New'
#  'Adult ENT Voice Coach New' 'Adult ENT Balance New'
#  'Adult ENT Voice Coach F/Up' 'Adult ENT Voice Osteopath New'
#  'Adult ENT Nurse Skin Test F/Up' 'Adult ENT Emergency Clinic New'
#  'Adult ENT Nurse Skin Test New' 'Adult ENT Thyroid Post Op F/Up'
#  'Adult ENT Emergency Nose Fracture New' 'Adult ENT Telephone F/Up'
#  'Adult ENT Nurse Dressing Clinic F/Up' 'Adult ENT Minor Ops F/Up'
#  'Adult ENT Nurse Dressing Clinic New']
# array([ 6, 23,  1,  8, 17, 20, 21, 22,  0, 13, 28, 14, 15,  3, 26, 18, 25,
#         2, 24, 27, 11,  4, 12, 19,  5, 16,  9,  7, 10])

# %%
# Encode the appointment_type column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(data["appointment_type"])

# Add the encoded column to the data
data["appointment_type_trans"] = label

# %%
# Encode the did_not_attend_risk_group column

risk_mapping ={
    "Low Risk": 1,
    "Moderate Risk": 2,
    "High Risk": 3,
    "Very High Risk": 4,
}

# Map the month names to numbers
data["did_not_attend_risk_group_trans"] = data["did_not_attend_risk_group"].map(risk_mapping)

data[['did_not_attend_risk_group', 'did_not_attend_risk_group_trans']]
# Out:
#        did_not_attend_risk_group  did_not_attend_risk_group_trans
# 0                      High Risk                                3
# 1                      High Risk                                3
# 2                       Low Risk                                1
# 3                       Low Risk                                1
# 4                      High Risk                                3
# ...                          ...                              ...
# 139238             Moderate Risk                                2
# 139239             Moderate Risk                                2
# 139240                 High Risk                                3
# 139241             Moderate Risk                                2
# 139242                 High Risk                                3
#
# [139243 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139243 entries, 0 to 139242
# Data columns (total 63 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   appointment_id                        139243 non-null  int64
#  1   age_deid                              139243 non-null  int64
#  2   bmi_deid                              139243 non-null  float64
#  3   ethnicity                             0 non-null       float64
#  4   ethnic_category_black                 139243 non-null  int64
#  5   ethnic_category_unknown               139243 non-null  int64
#  6   gender_male                           139243 non-null  int64
#  7   imd19_quintile                        139243 non-null  int64
#  8   main_spoken_language_other            139243 non-null  int64
#  9   current_smoker                        139243 non-null  int64
#  10  substance_misuse                      139243 non-null  int64
#  11  smoking_unknown                       139243 non-null  int64
#  12  tfc_name                              0 non-null       float64
#  13  patient_on_multiple_pathways          0 non-null       float64
#  14  appt_month                            139243 non-null  object
#  15  appt_hour                             139243 non-null  float64
#  16  appt_duration                         139243 non-null  float64
#  17  hospital_service_display              138846 non-null  object
#  18  service_mapping                       139243 non-null  object
#  19  reason_display                        139243 non-null  object
#  20  appointment_type                      139243 non-null  object
#  21  new_appt_flag                         139243 non-null  int64
#  22  appointment_type_telephone            139243 non-null  int64
#  23  appt_hour_11am_to_12pm                139243 non-null  int64
#  24  appt_hour_12pm_to_1pm                 139243 non-null  int64
#  25  appt_hour_2pm_to_3pm                  139243 non-null  int64
#  26  appt_season_winter                    139243 non-null  int64
#  27  days_last_appt                        139243 non-null  int64
#  28  emergency_enc_last_12m_one_or_two     139243 non-null  int64
#  29  emergency_enc_last_12m_three_or_more  139243 non-null  int64
#  30  lead_time                             139243 non-null  int64
#  31  ltc_count                             139243 non-null  int64
#  32  ns_rate_seq                           139243 non-null  float64
#  33  num_reschedules_one                   139243 non-null  int64
#  34  num_reschedules_two_or_more           139243 non-null  int64
#  35  op_appts_last_12m                     139243 non-null  int64
#  36  osrm_drive_time                       139243 non-null  float64
#  37  other_vulnerability                   139243 non-null  int64
#  38  past_no_show_count_one                139243 non-null  int64
#  39  past_no_show_count_three_or_more      139243 non-null  int64
#  40  past_no_show_count_two                139243 non-null  int64
#  41  past_no_show_rate                     139243 non-null  float64
#  42  phone_number                          139243 non-null  int64
#  43  physically_inactive                   139243 non-null  int64
#  44  safeguarding                          139243 non-null  int64
#  45  service_mapping_allied_hcp_therapy    139243 non-null  int64
#  46  service_mapping_paeds                 139243 non-null  int64
#  47  service_mapping_priority              139243 non-null  int64
#  48  service_mapping_surgical              139243 non-null  int64
#  49  weekswaiting                          0 non-null       float64
#  50  no_show                               139243 non-null  float64
#  51  did_not_attend_risk                   139243 non-null  float64
#  52  did_not_attend_risk_group             139243 non-null  object
#  53  prediction_type                       139243 non-null  object
#  54  case_control                          139243 non-null  float64
#  55  use_case                              139243 non-null  int64
#  56  appt_date                             139243 non-null  datetime64[ns]
#  57  appt_month_trans                      139243 non-null  int64
#  58  hospital_service_display_trans        139243 non-null  int64
#  59  service_mapping_trans                 139243 non-null  int64
#  60  reason_display_trans                  139243 non-null  int64
#  61  appointment_type_trans                139243 non-null  int64
#  62  did_not_attend_risk_group_trans       139243 non-null  int64
# dtypes: datetime64[ns](1), float64(13), int64(42), object(7)
# memory usage: 66.9+ MB

# %% [markdown]
# ### Export the transformed use case 3 data

# %%
# Dropped all transformed columns
data_trans = data.drop([
"appt_month",
"hospital_service_display",
"service_mapping",
"reason_display",
"appointment_type",
"did_not_attend_risk_group"], axis =1)

# Export data for use case 1 to CSV
data_trans.to_csv("../historic_appts_first_pred_trans.csv", index=False)
