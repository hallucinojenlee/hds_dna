# %%
import pandas as pd
from sklearn import preprocessing

# %%
# Import raw data
data = pd.read_csv("../de_id_data_v2_6.6.2024.csv")
data
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_67349/3435602546.py:2: DtypeWarning: Columns (3,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../de_id_data_v2_6.6.2024.csv")
#         appointment_id  age_deid  bmi_deid ethnicity  ethnic_category_black  \
# 0             10037229        12     27.45       NaN                      0
# 1             10079786        52     27.45       NaN                      0
# 2             10079786        52     39.45       NaN                      1
# 3             10098651         7     27.45       NaN                      1
# 4             10112206        22     18.00       NaN                      0
# ...                ...       ...       ...       ...                    ...
# 473151        13516860        57     39.45       NaN                      0
# 473152        13525823        62     39.45       NaN                      0
# ...

# %% [markdown]
# ### Split out data for use case 3 (historic appts)

# %%
# Split out data: use case 3 & case control 1 (case since model went live)
historic_data = data.loc[(data["use_case"]  == 3) & (data["case_control"] == 1)]
historic_data
# Out:
#         appointment_id  age_deid  bmi_deid ethnicity  ethnic_category_black  \
# 1             10079786        52     27.45       NaN                      0
# 2             10079786        52     39.45       NaN                      1
# 5             10164094        52     27.45       NaN                      1
# 6             10164094        52     27.45       NaN                      1
# 9             10211058        32     39.45       NaN                      0
# ...                ...       ...       ...       ...                    ...
# 473124        13390142        17     27.45       NaN                      1
# 473134        13440971        77     21.70       NaN                      0
# 473135        13440971        77     21.70       NaN                      0
# 473142        13463451        52     27.45       NaN                      1
# 473143        13463451        52     27.45       NaN                      1
#
# ...

# %%
# Check for missing values ie. columns aviailable for analysis
historic_data.isnull().sum()
# Out:
# appointment_id                               0
# age_deid                                     0
# bmi_deid                                     0
# ethnicity                               278799
# ethnic_category_black                        0
# ethnic_category_unknown                      0
# gender_male                                  0
# imd19_quintile                               0
# main_spoken_language_other                   0
# current_smoker                               0
# substance_misuse                             0
# smoking_unknown                              0
# referral_to_treatment_period_status     278799
# tfc_name                                278795
# patient_on_multiple_pathways            278799
# appt_month                                 208
# appt_hour                                  208
# appt_duration                              208
# hospital_service_display                  1002
# service_mapping                              0
# ...

# %%
# Export data before transformation
historic_data.to_csv("../historic_appts_raw.csv", index=False)

# %%
# count number of unique appointment IDs
historic_data[historic_data["case_control"]==1]["appointment_id"].nunique()
# Out:
# 139401

# %% [markdown]
# ### Transform date from object to datetime

# %%
historic_data["appt_date"] = pd.to_datetime(historic_data["appt_date"])
historic_data["appt_date"]
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_49703/3681495711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historic_data["appt_date"] = pd.to_datetime(historic_data["appt_date"])
# 1        2024-03-20
# 2        2024-03-20
# 5        2023-11-24
# 6        2023-11-24
# 9        2024-01-19
#             ...
# 473124   2024-03-11
# 473134   2024-03-20
# 473135   2024-03-20
# 473142   2024-01-30
# 473143   2024-01-30
# Name: appt_date, Length: 278799, dtype: datetime64[ns]

# %% [markdown]
# ### Transform categorical data to numeric data

# %%
historic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 278799 entries, 1 to 473143
# Data columns (total 58 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   appointment_id                        278799 non-null  int64
#  1   age_deid                              278799 non-null  int64
#  2   bmi_deid                              278799 non-null  float64
#  3   ethnicity                             0 non-null       object
#  4   ethnic_category_black                 278799 non-null  int64
#  5   ethnic_category_unknown               278799 non-null  int64
#  6   gender_male                           278799 non-null  int64
#  7   imd19_quintile                        278799 non-null  int64
#  8   main_spoken_language_other            278799 non-null  int64
#  9   current_smoker                        278799 non-null  int64
#  10  substance_misuse                      278799 non-null  int64
# ...

# %%
# Encode the appt_month column

month_mapping ={
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August": 8,
    "September": 9,
    "October": 10,
    "November": 11,
    "December": 12
}

# Map the month names to numbers
historic_data["appt_month_trans"] = historic_data["appt_month"].map(month_mapping)

historic_data[['appt_month', 'appt_month_trans']]
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_49703/2260487993.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historic_data["appt_month_trans"] = historic_data["appt_month"].map(month_mapping)
#        appt_month  appt_month_trans
# 1           March               3.0
# 2           March               3.0
# 5        November              11.0
# 6        November              11.0
# 9         January               1.0
# ...           ...               ...
# 473124      March               3.0
# 473134      March               3.0
# 473135      March               3.0
# 473142    January               1.0
# 473143    January               1.0
#
# [278799 rows x 2 columns]

# %%
# Encode the hospital_service_display column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(historic_data["hospital_service_display"])

# Add the encoded column to the data
historic_data["hospital_service_display_trans"] = label
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_49703/2175520591.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historic_data["hospital_service_display_trans"] = label

# %%
# Encode the service_mapping column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(historic_data["service_mapping"])

# Add the encoded column to the data
historic_data["service_mapping_trans"] = label
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_49703/60609214.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historic_data["service_mapping_trans"] = label

# %%
# Encode the reason_display column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(historic_data["reason_display"])

# Add the encoded column to the data
historic_data["reason_display_trans"] = label
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_49703/3015411435.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historic_data["reason_display_trans"] = label

# %%
# Find out the codes for reason_display that contain 'adult ENT'
print(historic_data[historic_data["reason_display"].str.contains("adult ENT", case=False, na=False)]["reason_display"].unique())
ent_appts = historic_data[historic_data["reason_display"].str.contains("adult ENT", case=False, na=False)]
ent_codes = ent_appts["reason_display_trans"].unique()
ent_codes
# Out:
# ['Adult ENT F/Up' 'Adult ENT Voice Clinic New' 'Adult ENT Balance F/Up'
#  'Adult ENT New' 'Adult ENT Thyroid F/Up' 'Adult ENT Voice Clinic F/Up'
#  'Adult ENT Voice Clinic JT F/Up' 'Adult ENT Voice Clinic JT New'
#  'Adult ENT BIPP F/Up' 'Adult ENT Post Op F/Up'
#  'Adult ENT Voice Post Op F/Up' 'Adult ENT Pre-Assessment F/Up'
#  'Adult ENT Results F/Up' 'Adult ENT Emergency Clinic F/Up'
#  'Adult ENT Voice Osteopath F/Up' 'Adult ENT Thyroid New'
#  'Adult ENT Voice Coach New' 'Adult ENT Balance New'
#  'Adult ENT Voice Coach F/Up' 'Adult ENT Voice Osteopath New'
#  'Adult ENT Nurse Skin Test F/Up' 'Adult ENT Emergency Clinic New'
#  'Adult ENT Nurse Skin Test New' 'Adult ENT Thyroid Post Op F/Up'
#  'Adult ENT Emergency Nose Fracture New' 'Adult ENT Telephone F/Up'
#  'Adult ENT Nurse Dressing Clinic F/Up' 'Adult ENT Minor Ops F/Up'
#  'Adult ENT Nurse Dressing Clinic New']
# array([ 6, 23,  1,  8, 17, 20, 21, 22,  0, 13, 28, 14, 15,  3, 26, 18, 25,
# ...

# %%
# Encode the appointment_type column

# Create a label encoder object
le = preprocessing.LabelEncoder()

# Fit the label encoder
label = le.fit_transform(historic_data["appointment_type"])

# Add the encoded column to the data
historic_data["appointment_type_trans"] = label
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_49703/3315754499.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historic_data["appointment_type_trans"] = label

# %%
# Encode the did_not_attend_risk_group column

risk_mapping ={
    "Low Risk": 1,
    "Moderate Risk": 2,
    "High Risk": 3,
    "Very High Risk": 4,
}

# Map the month names to numbers
historic_data["did_not_attend_risk_group_trans"] = historic_data["did_not_attend_risk_group"].map(risk_mapping)

historic_data[['did_not_attend_risk_group', 'did_not_attend_risk_group_trans']]
# Out:
# /var/folders/0t/dc47jt692_qc1qb7bqkgylhw0000gn/T/ipykernel_49703/2883965297.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historic_data["did_not_attend_risk_group_trans"] = historic_data["did_not_attend_risk_group"].map(risk_mapping)
#        did_not_attend_risk_group  did_not_attend_risk_group_trans
# 1                      High Risk                                3
# 2                      High Risk                                3
# 5                  Moderate Risk                                2
# 6                      High Risk                                3
# 9                       Low Risk                                1
# ...                          ...                              ...
# ...

# %%
historic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 278799 entries, 1 to 473143
# Data columns (total 64 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   appointment_id                        278799 non-null  int64
#  1   age_deid                              278799 non-null  int64
#  2   bmi_deid                              278799 non-null  float64
#  3   ethnicity                             0 non-null       object
#  4   ethnic_category_black                 278799 non-null  int64
#  5   ethnic_category_unknown               278799 non-null  int64
#  6   gender_male                           278799 non-null  int64
#  7   imd19_quintile                        278799 non-null  int64
#  8   main_spoken_language_other            278799 non-null  int64
#  9   current_smoker                        278799 non-null  int64
#  10  substance_misuse                      278799 non-null  int64
# ...

# %% [markdown]
# ### Export the transformed use case 3 data

# %%
# Dropped all transformed columns
historic_data_trans = historic_data.drop([
"appt_month",
"hospital_service_display",
"service_mapping",
"reason_display",
"appointment_type",
"did_not_attend_risk_group"], axis =1)

# Export data for use case 1 to CSV
historic_data_trans.to_csv("../historic_appts_trans.csv", index=False)
